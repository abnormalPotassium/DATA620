# %% [markdown]
# <a href="https://colab.research.google.com/github/abnormalPotassium/DATA620/blob/main/Environment/EnvSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing Conda for Google Colab to save and replicate environments

# %%
# !pip install condacolab

# %%
import condacolab

# %%
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %% [markdown]
# Checking if Conda was successfully installed

# %%
# !conda --version
# Out:
# conda 23.1.0

# %% [markdown]
# Installing packages to our Conda environment:
# - networkx for creating network graphs
# - nltk for text mining
# - pyvis for better network dataset visualization

# %%
# !conda install networkx
# !conda install nltk
# !conda install pyvis
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - networkx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.2.2   |       hbcca054_0         152 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     networkx-3.2.1             |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     openssl-3.2.1              |       hd590300_0         2.7 MB  conda-forge
#     python_abi-3.10            |          4_cp310           6 KB  conda-forge
# ...

# %%
# !conda env export -f data620conda.yml

# %% [markdown]
# # Requirements.txt

# %% [markdown]
# Install the packages you want to use and session info to track them after import.

# %%
# !pip install session-info
# !pip install networkx
# !pip install nltk
# !pip install pyvis
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 4.8 MB/s eta 0:00:00
# ...
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8027 sha256=cd10dc5d658b9cf6828afd68cea52dee9d6f4ad1c2a342c61eba47d74214ff6d
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import the packages you want to use.

# %%
import networkx
import nltk
import pyvis

# %% [markdown]
# Get your session info.

# %%
import session_info

session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# networkx            3.2.1
# nltk                3.8.1
# pyvis               0.3.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.4.0
# backcall            0.2.0
# certifi             2024.02.02
# cffi                1.16.0
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           4.4.2
# defusedxml          0.7.1
# google              NA
# httplib2            0.22.0
# ipykernel           5.5.6
# ipython_genutils    0.2.0
# jinja2              3.1.3
# joblib              1.3.2
# jsonpickle          3.0.3
# kiwisolver          1.4.5
# markupsafe          2.1.5
# matplotlib          3.7.1
# matplotlib_inline   0.1.6
# mpl_toolkits        NA
# numpy               1.25.2
# packaging           23.2
# pexpect             4.9.0
# ...

# %% [markdown]
# Write your session info to requirements.txt

# %%
session_info.show(write_req_file=True, req_file_name='requirements.txt')
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# networkx            3.2.1
# nltk                3.8.1
# pyvis               0.3.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.4.0
# backcall            0.2.0
# certifi             2024.02.02
# cffi                1.16.0
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           4.4.2
# defusedxml          0.7.1
# google              NA
# httplib2            0.22.0
# ipykernel           5.5.6
# ipython_genutils    0.2.0
# jinja2              3.1.3
# joblib              1.3.2
# jsonpickle          3.0.3
# kiwisolver          1.4.5
# markupsafe          2.1.5
# matplotlib          3.7.1
# matplotlib_inline   0.1.6
# mpl_toolkits        NA
# numpy               1.25.2
# packaging           23.2
# pexpect             4.9.0
# ...
